# %% [markdown]
# ## Tempo até o próximo ano
#
# Crie um script Python que calcula quantos dias, horas, minutos e segundos faltam até o próximo Ano Novo.

# %% [markdown]
# Lembrar da tupla de struct_time: https://docs.python.org/3/library/time.html#time.struct_time

# %%
segundos_por_minuto = 60
segundos_por_hora = 60 * 60
segundos_por_dia = 24 * 60 * 60

print(f"Segundos em um minuto: {segundos_por_minuto} s")
print(f"Segundos em uma hora: {segundos_por_hora} s")
print(f"Segundos em um dia: {segundos_por_dia} s")

# %% [markdown]
# Lembrando de divisão:
#
# ![divisao](https://escolaeducacao.com.br/wp-content/uploads/2020/01/algoritmo-divisao.png)

# %%
import time

tempo_atual = time.gmtime()

print(tempo_atual)

tempo_ano_novo = time.mktime((2025, 1, 1, 0, 0, 0, 0, 0, 0))

print(tempo_ano_novo)

diferenca_segundos = time.mktime(tempo_atual) - tempo_ano_novo
diferenca_minutos = diferenca_segundos//60
diferenca_horas = diferenca_minutos//60
diferenca_dias = diferenca_horas//24



print(f'Faltam {int(diferenca_segundos*-1)} segundos para o ano novo.')
print(f'Faltam {int(diferenca_minutos*-1)} minutos para o ano novo.')
print(f'Fatam {int(diferenca_horas*-1)} horas para o ano novo.')
print(f'Faltam {int(diferenca_dias*-1)} dias para o ano novo.')
# Out:
# time.struct_time(tm_year=2024, tm_mon=7, tm_mday=10, tm_hour=8, tm_min=43, tm_sec=22, tm_wday=2, tm_yday=192, tm_isdst=0)
# 1735689600.0
# Faltam 15088598 segundos para o ano novo.
# Faltam 251477 minutos para o ano novo.
# Fatam 4192 horas para o ano novo.
# Faltam 175 dias para o ano novo.
