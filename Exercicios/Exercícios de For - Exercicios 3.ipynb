# %% [markdown]
# # Exercícios
#
# ## 1. Calculando % de uma lista
#
# Faremos algo parecido com "filtrar" uma lista. Mais pra frente no curso aprenderemos outras formas de fazer isso, mas com o nosso conhecimentoa atual já conseguimos resolver o desafio.
#
# Digamos que a gente tenha uma lista de vendedores e ao invés de saber todos os vendedores que bateram a meta, eu quero conseguir calcular o % de vendedores que bateram a meta. Ou seja, se temos 10 vendedores e 3 bateram a meta, temos 30% dos vendedores que bateram a meta.

# %%
meta = 10000
vendas = [
    ['João', 15000],
    ['Julia', 27000],
    ['Marcus', 9900],
    ['Maria', 3750],
    ['Ana', 10300],
    ['Alon', 7870],
]
# Out:
# João bateu a meta
# ...
# Julia bateu a meta
# ...
# Marcus não bateu a meta
# ...
# Maria não bateu a meta
# ...
# Ana bateu a meta
# ...
# Alon não bateu a meta
# ...
# 50% dos vendedores bateram a meta.

# %% [markdown]
# - Vamos resolver de 2 formas:
#     1. Criando uma lista auxiliar apenas com os vendedores que bateram a meta
#     2. Fazendo o cálculo diretamente na lista que já temos

# %% [markdown]
# ## Para treinar uma estrutura parecida, crie um código para responder: quem foi o vendedor que mais vendeu?

# %%
# Resolvendo com o cálculo direto, sem lista auxiliar
bateu_meta = 0

for i, venda in enumerate(vendas):
    if venda[1] >= meta:
        bateu_meta += 1
        print(f'{venda[0]} bateu a meta')
        print('='*50)
    else:
        print(f'{venda[0]} não bateu a meta')
        print('='*50)

print(f"{(bateu_meta/len(vendas)):.0%} dos vendedores bateram a meta.")
# Out:
# João bateu a meta
# ...
# Julia bateu a meta
# ...
# Marcus não bateu a meta
# ...
# Maria não bateu a meta
# ...
# Ana bateu a meta
# ...
# Alon não bateu a meta
# ...
# 50% dos vendedores bateram a meta.

# %%
# Resolvendo com lista auxiliar:

vendas_meta = []
porcentagem_vendedores_bateram_meta = 0

for i, venda in enumerate(vendas):
    if venda[1] >= meta:
        vendas_meta.append(venda[0])
        porcentagem_vendedores_bateram_meta = len(vendas_meta)/len(vendas)
    else:
        pass

print(f"A porcentagem de vendedores que bateram a meta é de {porcentagem_vendedores_bateram_meta:.0%}")
# Out:
# A porcentagem de vendedores que bateram a meta é de 50%
